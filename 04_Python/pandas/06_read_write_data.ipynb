# %%
import pandas as pd

# %% [markdown]
# Read/write data from csv

# %%
df = pd.read_csv('survey_dataset.csv')

# %%
df
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# ...

# %%
# Filtered data
filt = (df['Country'] =='India')
india_df = (df[filt])
india_df
# Out:
#        ResponseId                                         MainBranch  \
# 17             18                     I am a developer by profession
# 58             59  I am not primarily a developer, but I write co...
# 75             76                              I am learning to code
# 89             90                              I am learning to code
# 96             97                     I am a developer by profession
# ...           ...                                                ...
# 65339       65340  I am not primarily a developer, but I write co...
# 65383       65384                              I am learning to code
# 65413       65414                              I am learning to code
# 65415       65416                        I code primarily as a hobby
# 65428       65429                     I am a developer by profession
#
#                    Age                                         Employment  \
# ...

# %%
# Write data to csv
india_df.to_csv('write_survey.csv')   #data seperated by ,

# %%
# write data to tsv file
india_df.to_csv('write_tsv_survey.tsv',sep = '\t')

# %% [markdown]
# Read/write data from excel file

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\aditi\anaconda3\python.exe

# %%
# %pip install openpyxl xlwt xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#write data to excel file
india_df.to_excel('data.xlsx')

# %%
#read data from excel file
test = pd.read_excel('data.xlsx',index_col='ResponseId')
test
# Out:
#             Unnamed: 0                                         MainBranch  \
# ResponseId
# 18                  17                     I am a developer by profession
# 59                  58  I am not primarily a developer, but I write co...
# 76                  75                              I am learning to code
# 90                  89                              I am learning to code
# 97                  96                     I am a developer by profession
# ...                ...                                                ...
# 65340            65339  I am not primarily a developer, but I write co...
# 65384            65383                              I am learning to code
# 65414            65413                              I am learning to code
# 65416            65415                        I code primarily as a hobby
# 65429            65428                     I am a developer by profession
#
#                         Age  \
# ResponseId
# ...

# %% [markdown]
# Read/write from JSON file

# %%
india_df.to_json('json_data.json',orient='records',lines=True)

# %%
#Read from json file
test = pd.read_json('json_data.json',orient='records',lines=True)

# %%
test
# Out:
#       ResponseId                                         MainBranch  \
# 0             18                     I am a developer by profession
# 1             59  I am not primarily a developer, but I write co...
# 2             76                              I am learning to code
# 3             90                              I am learning to code
# 4             97                     I am a developer by profession
# ...          ...                                                ...
# 4226       65340  I am not primarily a developer, but I write co...
# 4227       65384                              I am learning to code
# 4228       65414                              I am learning to code
# 4229       65416                        I code primarily as a hobby
# 4230       65429                     I am a developer by profession
#
#                   Age                                         Employment  \
# 0     18-24 years old  Independent contractor, freelancer, or self-em...
# ...

# %% [markdown]
# Read data from URL method

# %%
post_df = pd.read_csv('https://media.githubusercontent.com/media/StackExchange/Survey/refs/heads/main/packages/archive/2024/results.csv')

# %%
post_df.shape
# Out:
# (65437, 114)

# %% [markdown]
# Read/write data from sql

# %%
# %pip install SQLAlchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install psycopg2-binary
# Out:
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------- ----- 2.4/2.8 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 13.2 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# %%
import psycopg2

# %%
#create a new table into sql
# india_df.to_sql('india-survey')

# %%
# engine = create_engine('post')
